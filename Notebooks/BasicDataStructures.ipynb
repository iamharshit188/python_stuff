# %%
fruits=["superman" , "baba" , "shinchan" , "google", "apple" , "amazon" , "flipkart" , "mytra" , "baba" , "shinchan" , "google", "apple" , "amazon" , "flipkart" , "mytra" ]
print(fruits)
numbers = [ 1 , 2 ,3 ,4 ]
print(numbers)
print(numbers[ -3])
print(fruits [ -3 ])
print(fruits[0:4])
print(fruits[::5])
# Out:
# ['superman', 'baba', 'shinchan', 'google', 'apple', 'amazon', 'flipkart', 'mytra', 'baba', 'shinchan', 'google', 'apple', 'amazon', 'flipkart', 'mytra']
# [1, 2, 3, 4]
# 2
# amazon
# ['superman', 'baba', 'shinchan', 'google']
# ['superman', 'amazon', 'google']

# %%
# We can add list with + operator directly

li1 = [ "superman" , "baba" , "shinchan" , "google", "apple" , "amazon" , "flipkart" , "mytra" ] 
numbers = [ 1 , 2 ,3 ,4 ]

# final = numbers + li1
li1.extend(numbers)
print(final)
# li1.append("newAppended")
# print(li1)
# li1.pop(1 , 3)
# print(li1)
print()
final.count("apple")
# Out:
# [1, 2, 3, 4, 'superman', 'baba', 'shinchan', 'google', 'apple', 'amazon', 'flipkart', 'mytra']
# 1
